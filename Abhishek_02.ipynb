# %%
import pandas as pd
import numpy as np

# %%
student = pd.read_csv('students.csv')

# %%
student.head()
# Out:
#      name  age   regid  ohy  chem  math  bio  avd  rank
# 0   vijay   14  HPE001   99    98    97   96    0     0
# 1   gokul   14  HPE001   91    88    77   96    0     0
# 2    maxi   14  HPE001   90    98    95   96    0     0
# 3  Albaas   14  HPE001   91    92    90   93    0     0
# 4  prasad   14  HPE001   99    98    95   99    0     0

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
# name     5 non-null object
# age      5 non-null int64
# regid    5 non-null object
# ohy      5 non-null int64
# chem     5 non-null int64
# math     5 non-null int64
# bio      5 non-null int64
# avd      5 non-null int64
# rank     5 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 488.0+ bytes

# %%
student['avg']=student[['ohy','chem','math','bio']].mean(axis=1)

# %%
student
# Out:
#      name  age   regid  ohy  chem  math  bio  avd  rank    avg
# 0   vijay   14  HPE001   99    98    97   96    0     0  97.50
# 1   gokul   14  HPE001   91    88    77   96    0     0  88.00
# 2    maxi   14  HPE001   90    98    95   96    0     0  94.75
# 3  Albaas   14  HPE001   91    92    90   93    0     0  91.50
# 4  prasad   14  HPE001   99    98    95   99    0     0  97.75

# %%
student.drop(['avd','rank'], axis=1,inplace=True)

# %%
student
# Out:
#      name  age   regid  ohy  chem  math  bio    avg
# 0   vijay   14  HPE001   99    98    97   96  97.50
# 1   gokul   14  HPE001   91    88    77   96  88.00
# 2    maxi   14  HPE001   90    98    95   96  94.75
# 3  Albaas   14  HPE001   91    92    90   93  91.50
# 4  prasad   14  HPE001   99    98    95   99  97.75

# %%
student['rank'] = student ['avg'].rank(ascending=False)

# %%
student
# Out:
#      name  age   regid  ohy  chem  math  bio    avg  rank
# 0   vijay   14  HPE001   99    98    97   96  97.50   2.0
# 1   gokul   14  HPE001   91    88    77   96  88.00   5.0
# 2    maxi   14  HPE001   90    98    95   96  94.75   3.0
# 3  Albaas   14  HPE001   91    92    90   93  91.50   4.0
# 4  prasad   14  HPE001   99    98    95   99  97.75   1.0

# %%
student.to_csv("New Student.csv")
